# %%
import cv2
import matplotlib.pyplot as plt

# %%
path=r"C:\Users\GIGABYTE\OneDrive - NTNU\Desktop\Capture.PNG"

# %%
image=cv2.imread(path,0)
cv2.imshow("image",image)
cv2.waitKey(2000)
cv2.destroyAllWindows()

# %%
# flag
# image=cv2.imread(path,1)
# print(image.shape)


# or
# image=cv2.imread(path,cv2.IMREAD_GRAYSCALE)
# print(image.shape)

# %%
image=cv2.imread(path)
cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image)

# %% [markdown]
# # showing image

# %%
image=cv2.imread(path)
cv2.imshow("this_name_is_given_by_me",image)
cv2.waitKey(2000)
cv2.destroyAllWindows()

# %%
# google colab =>from google.colab.patches import cv2_imshow
  
# window_name = "Image"
  
# cv2_imshow(img)  # Pay special attention to "_" (underscore)

# %% [markdown]
# # writing image

# %%
image=cv2.imread(path)
cv2.imwrite("./here.jpg",image)
# Out:
# True

# %% [markdown]
# # color spaces

# %%
image=cv2.imread(path)
B,G,R=cv2.split(image)
cv2.imshow("original", image)
cv2.waitKey(0)
cv2.imshow("blue", B)
cv2.waitKey(0)
cv2.imshow("Green", G)
cv2.waitKey(0)
cv2.imshow("red", R)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # arithmetic operation

# %% [markdown]
# Syntax: cv2.addWeighted(img1, wt1, img2, wt2, gammaValue)
# Parameters:
# img1: First Input Image array(Single-channel, 8-bit or floating-point)
# wt1: Weight of the first input image elements to be applied to the final image
# img2: Second Input Image array(Single-channel, 8-bit or floating-point)
# wt2: Weight of the second input image elements to be applied to the final image
# gammaValue: Measurement of light

# %%
image=cv2.imread(path)
image2=cv2.imread("./here.jpg")
plt.imshow(cv2.addWeighted(image,0.5, image2,0.2,0))

# %% [markdown]
# # subtract the image

# %%
image=cv2.imread(path)
image2=cv2.imread("./here.jpg")

subtract_image=cv2.subtract(image,image2)
plt.imshow(subtract_image)

# %% [markdown]
# # arthimetic operation

# %% [markdown]
# Bitwise operations are used in image manipulation and used for extracting essential parts in the image. In this article, Bitwise operations used are :
#
#
# AND
# OR
# XOR
# NOT

# %%
image=cv2.imread("./imag1.png")
image2=cv2.imread("./image2.png")

bitwise_and=cv2.bitwise_and(image,image2,mask=None)
plt.imshow(bitwise_and)

# %%
image=cv2.imread("./imag1.png")
image2=cv2.imread("./image2.png")

bitwise_and=cv2.bitwise_or(image,image2,mask=None)
plt.imshow(bitwise_and)

# %%
image=cv2.imread("./imag1.png")
image2=cv2.imread("./image2.png")

bitwise_and=cv2.bitwise_xor(image,image2,mask=None)
plt.imshow(bitwise_and)

# %%
image=cv2.imread("./imag1.png")
image2=cv2.imread("./image2.png")

bitwise_and=cv2.bitwise_not(image,image2,mask=None)
plt.imshow(bitwise_and)

# %%
image=cv2.imread("./imag1.png")
image2=cv2.imread("./image2.png")

bitwise_and=cv2.bitwise_not(image2,mask=None)
plt.imshow(bitwise_and)

# %%
image=cv2.imread("./imag1.png")
image2=cv2.imread("./image2.png")

bitwise_and=cv2.bitwise_not(image,mask=None)
plt.imshow(bitwise_and)

# %%
plt.imshow(image)
