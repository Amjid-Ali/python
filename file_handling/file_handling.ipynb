# %% [markdown]
# ### Some Theory
#
# ##### Types of data used for I/O:
# - Text - '12345' as a sequence of unicode chars
# - Binary - 12345 as a sequence of bytes of its binary equivalent
#
# ##### Hence there are 2 file types to deal with
# - Text files - All program files are text files
# - Binary Files - Images,music,video,exe files

# %% [markdown]
# ### How File I/O is done in most programming languages
#
# - Open a file
# - Read/Write data
# - Close the file

# %% [markdown]
# ### Writing to a file

# %%
# case 1 - if the file is not present
f = open('sample.txt','w')
f.write('Hello world')
f.close()
# since file is closed hence this will not work
f.write('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-c02a4a856526> in <module>
#       3 f.write('Hello world')
#       4 f.close()
# ----> 5 f.write('hello')
#
# ValueError: I/O operation on closed file.

# %%
f=open("wali1.txt","w")

# %%
f.write("this is wali khan")
f.write("\nthis is new line")
f.write("\nUmar is helicopeter")
f.close()

# %%
# write multiline strings
f = open('sample1.txt','w')
f.write('hello world')
f.write('\nhow are you?')
f.close()

# %%
# case 2 - if the file is already present
f = open('sample.txt','w')
f.write('salman khan')
f.close()

# %%
f=open("./wali.txt",'w') 
f.write("the is added now")
f.close()

# %%
# how exactly open() works?

f=open("./wali.txt",'a')
f.write("\tappend to wali khan new line")
f.close()

# %%
# Problem with w mode
# introducing append mode
f = open('/content/sample1.txt','a')
f.write('\nI am fine')
f.close()

# %%
# write lines
L = ['hello\n','hi\n','how are you\n','I am fine']

f = open('/content/temp/sample.txt','w')
f.writelines(L)
f.close()

# %%
data=["hello this is data","i need to append into the file","finsih"]

# data="this is data"

# data='''
# lsjflkdjlkf sdlkfsd
# sjdflsdjfl
# sdjflsdjf;sdl
# '''

f=open("./wali.txt",'w')
f.writelines(data)
f.close()

# %%
# reading from files
# -> using read()
f = open('/content/sample.txt','r')
s = f.read()
print(s)
f.close()
# Out:
# hello
# hi
# how are you
# I am fine

# %%
f=open("./wali.txt",'r')
print(f.read())
# print(s)
f.close()
# Out:
# hello this is datai need to append into the filefinsih

# %%
# reading upto n chars
f = open('/content/sample.txt','r')
s = f.read(10)
print(s)
f.close()
# Out:
# hello
# hi
# h

# %%
f=open("./wali.txt",'r')
print(f.read(10))
# print(s)
f.close()
# Out:
# hello this

# %%
# readline() -> to read line by line
f = open('/content/sample.txt','r')
print(f.readline(),end='')
print(f.readline(),end='')
f.close()
# Out:
# hello
# hi

# %%
f=open("./wali.txt",'r')
# print(type(f.readline()))
print(f.readlines())
# print(len(f.readline()))
# print(len(f.readline()))
f.close()
# Out:
# ['hello this is datai need to append into the filefinsih\n', 'this is umer khan, and he is helicoptor\n', 'hello this is datai need to append into the filefinsih']

# %%
# reading entire using readline
f = open('/content/sample.txt','r')

while True:

  data = f.readline()

  if data == '':
    break
  else:
    print(data,end='')

f.close()
# Out:
# hello
# hi
# how are you
# I am fine

# %%
f=open("./wali.txt",'r')
while True:
    data=f.readline()
    if data=='':
        break
    else:
        print(data,end=" ")
f.close()
# Out:
# hello this is datai need to append into the filefinsih
#  this is umer khan, and he is helicoptor
#  hello this is datai need to append into the filefinsih

# %% [markdown]
# ### Using Context Manager (With)
#
# - It's a good idea to close a file after usage as it will free up the resources
# - If we dont close it, garbage collector would close it
# - with keyword closes the file as soon as the usage is over

# %%
# with
with open('/content/sample1.txt','w') as f:
  f.write('selmon bhai')

# %%
with open("./waheed.txt",'w') as f:
    f.write("this is waheed khan/")

# %%
# f.write('hello')

# f.write("hel")

# %%
# try f.read() now
with open('/content/sample.txt','r') as f:
  print(f.readline())
# Out:
# hello

# %%
# moving within a file -> 10 char then 10 char
with open('sample.txt','r') as f:
  print(f.read(10))
  print(f.read(10))
  print(f.read(10))
  print(f.read(10))
# Out:
# hello
# hi
# h
# ow are you
#
# I am fine

# %%
# benefit? -> to load a big file in memory
big_L = ['hello world ' for i in range(1000)]

with open('big.txt','w') as f:
  f.writelines(big_L)

# %%
with open('big.txt','r') as f:

  chunk_size = 10

  while len(f.read(chunk_size)) > 0:
    print(f.read(chunk_size),end='***')
    f.read(chunk_size)
# Out:
# d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo
# ...

# %%
# seek and tell function
with open('sample.txt','r') as f:
  f.seek(15)
  print(f.read(10))
  print(f.tell())
  
  print(f.read(10))
  print(f.tell())
# Out:
# e you
# I am
# 25
#  fine
# 30

# %%
with open("./waheed.txt",'r') as f:
    f.seek(2)
    print(f.read())
    print(f.tell())
# Out:
# is is waheed khan/
# 20

# %%
# seek during write
with open('sample.txt','w') as f:
  f.write('Hello')
  f.seek(0)
  f.write('Xa')

# %%
with open("./waheed.txt",'w') as waheed:
    waheed.write("hello")
    waheed.seek(0)
    waheed.write("X")

# %% [markdown]
# ### Problems with working in text mode
#
# - can't work with binary files like images
# - not good for other data types like int/float/list/tuples

# %%
# working with binary file
with open('./sreenshot_copy.jpg','r') as f:
  f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-64-d1ee59a32e76> in <module>
#       1 # working with binary file
#       2 with open('./sreenshot_copy.jpg','r') as f:
# ----> 3   f.read()
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xff in position 0: illegal multibyte sequence

# %%
with open("./sreenshot_copy.jpg",'rb') as f:
    print(f.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe2\x0cXICC_PROFILE\x00\x01\x01\x00\x00\x0cHLino\x02\x10\x00\x00mntrRGB XYZ \x07\xce\x00\x02\x00\t\x00\x06\x001\x00\x00acspMSFT\x00\x00\x00\x00IEC sRGB\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-HP  \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x11cprt\x00\x00\x01P\x00\x00\x003desc\x00\x00\x01\x84\x00\x00\x00lwtpt\x00\x00\x01\xf0\x00\x00\x00\x14bkpt\x00\x00\x02\x04\x00\x00\x00\x14rXYZ\x00\x00\x02\x18\x00\x00\x00\x14gXYZ\x00\x00\x02,\x00\x00\x00\x14bXYZ\x00\x00\x02@\x00\x00\x00\x14dmnd\x00\x00\x02T\x00\x00\x00pdmdd\x00\x00\x02\xc4\x00\x00\x00\x88vued\x00\x00\x03L\x00\x00\x00\x86view\x00\x00\x03\xd4\x00\x00\x00$lumi\x00\x00\x03\xf8\x00\x00\x00\x14meas\x00\x00\x04\x0c\x00\x00\x00$tech\x00\x00\x040\x00\x00\x00\x0crTRC\x00\x00\x04<\
# ...

# %%
# working with binary file
with open('./sreenshot_copy.jpg','rb') as f:
  with open('waheed.png','wb') as wf:
    wf.write(f.read())

# %%
# working with a big binary file

# %%
# working with other data types
with open('sample.txt','w') as f:
  f.write(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-a8e7a73b1431> in <module>
#       1 # working with other data types
#       2 with open('sample.txt','w') as f:
# ----> 3   f.write(5)
#
# TypeError: write() argument must be str, not int

# %%
with open('sample.txt','w') as f:
  f.write('5')

# %%
with open('sample.txt','r') as f:
  print(int(f.read()) + 5)
# Out:
# 10

# %%
# more complex data
d = {
    'name':'nitish',
     'age':33,
     'gender':'male'
}

with open('sample.txt','w') as f:
  f.write(str(d))

# %%
with open('sample.txt','r') as f:
  print(type(f.read()))
# Out:
# <class 'str'>

# %% [markdown]
# ### Serialization and Deserialization
#
# - **Serialization** - process of converting python data types to JSON format
# - **Deserialization** - process of converting JSON to python data types
#
# #### What is JSON?
#
#
# ![image.png](data:image/png;base64,...)

# %%
# serialization using json module
# list
import json

L = [1,2,3,4]

with open('demo.json','w') as f:
  json.dump(L,f)

# %%
import json
l=[1,2,3,3]
with open("./json.json",'w') as f:
    json.dump(l,f)

# %%
# dict
d = {
    'name':'nitish',
     'age':33,
     'gender':'male'
}

with open('demo.json','w') as f:
  json.dump(d,f,indent=4)

# %%
# deserialization
import json

with open('demo.json','r') as f:
  d = json.load(f)
  print(d)
#   print(type(d))
# Out:
# {'name': 'a', 'lname': 'b', 'age': 1, 'gender': 'male'}

# %%
# serialize and deserialize tuple
import json

t = (1,2,3,4,5)

with open('tuple.json','w') as f:
  json.dump(t,f)

# %%
# serialize and deserialize a nested dict

d = {
    'student':'nitish',
     'marks':[23,14,34,45,56]
}

with open('demo.json','w') as f:
  json.dump(d,f)

# %% [markdown]
# ### Serializing and Deserializing custom objects

# %%
class Person:

  def __init__(self,fname,lname,age,gender):
    self.fname = fname
    self.lname = lname
    self.age = age
    self.gender = gender

# format to printed in
# -> Nitish Singh age -> 33 gender -> male

# %%
# person = Person('Nitish','Singh',33,'male')




def serializer(obj):
    return obj.fname,obj.lname,obj.age

# %%
with open("./file.json",'w') as f:
    json.dump(person,f,default=serializer)

# %%
# As a string
import json

def show_object(person):
  if isinstance(person,Person):
    return "{} {} age -> {} gender -> {}".format(person.fname,person.lname,person.age,person.gender)

with open('demo.json','w') as f:
  json.dump(person,f,default=show_object)

# %%
# As a dict
import json

def show_object(person):
  if isinstance(person,Person):
    return {'name':person.fname + ' ' + person.lname,'age':person.age,'gender':person.gender}

with open('demo.json','w') as f:
  json.dump(person,f,default=show_object,indent=4)

# %%
# indent arrtribute
# As a dict

# %%
# deserializing
import json

with open('demo.json','r') as f:
  d = json.load(f)
  print(d)
  print(type(d))
# Out:
# {'name': 'Nitish Singh', 'age': 33, 'gender': 'male'}
# <class 'dict'>

# %% [markdown]
# ### Pickling
# `Pickling` is the process whereby a Python object hierarchy is converted into a byte stream, and `unpickling` is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy.

# %%
class Person:

  def __init__(self,name,age):
    self.name = name
    self.age = age

  def display_info(self):
    print('Hi my name is',self.name,'and I am ',self.age,'years old')

# %%
p = Person('nitish',33)

# %%
# pickle dump
import pickle
with open('person.pkl','wb') as f:
  pickle.dump(p,f)

# %%
# pickle load
import pickle
with open('person.pkl','rb') as f:
  p = pickle.load(f)

p.display_info()
# Out:
# Hi my name is nitish and I am  33 years old

# %% [markdown]
# ### Pickle Vs Json
#
# - Pickle lets the user to store data in binary format. JSON lets the user store data in a human-readable text format.
